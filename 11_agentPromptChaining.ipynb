# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
class BlogState(TypedDict):
    topic:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:

    # fetch title
    title = state['topic']
    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title = state['topic']

    outline = state['outline']

    prompt = f'Write a detailed blog on the title {title} using the following outline {outline}'

    content = model.invoke(prompt).content

    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

# adding nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)


# adding edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initialState = {'topic':'Market Analysis'}

finalState = workflow.invoke(initialState)
print(finalState)
# Out:
# {'topic': 'Market Analysis', 'outline': 'Here\'s a detailed outline for a blog post on "Market Analysis," designed to be comprehensive, engaging, and actionable for readers.\n\n---\n\n## Blog Title Ideas:\n\n*   Market Analysis: Your Ultimate Compass for Business Success\n*   Navigate the Business Landscape: A Comprehensive Guide to Market Analysis\n*   Unlock Growth: The Power of Strategic Market Analysis\n*   Beyond Gut Feeling: Why Market Analysis is Your Business Superpower\n*   Mastering Market Analysis: From Data to Dominance\n\n---\n\n## Detailed Blog Outline: Market Analysis: Your Ultimate Compass for Business Success\n\n**Target Audience:** Entrepreneurs, small business owners, marketing professionals, product managers, aspiring business strategists.\n\n**Goal:** To educate readers on what market analysis is, why it\'s crucial, how to conduct it effectively, and how to leverage its insights for strategic decision-making and business growth.\n\n---\n\n### I. Introduction: Setting the Stage (Approx. 150 words)\n\n*   **A. Hook:** Start with a relatable scenario – the uncertainty of launching a product, entering a new market, or facing stiff competition. "Ever felt like you\'re sailing a ship without a map in the vast ocean of business?"\n*   **B. Introduce Market Analysis:** Briefly define it as the systematic process of gathering, analyzing, and interpreting information about a market, including its customers, competitors, and trends.\n*   **C. State the Blog\'s Purpose:** Emphasize that this guide will demystify market analysis, showing readers why it\'s indispensable and how to perform it to gain a competitive edge.\n*   **D. Thesis Statement:** Market analysis isn\'t just a buzzword; it\'s the bedrock of informed decision-making, risk reduction, and sustainable growth for any business.\n\n### II. What Exactly is Market Analysis & Why Does It Matter? (Approx. 200 words)\n\n*   **A. Deeper Definition:**\n    *   More than just data collection; it\'s about understanding the "why" behind market dynamics.\n    *   Encompasses demand, supply, pricing, competition, customer behavior, and future potential.\n*   **B. Why It\'s Indispensable: The Core Benefits**\n    *   **1. Informed Decision-Making:** Move beyond assumptions and gut feelings.\n    *   **2. Identify Opportunities & Threats:** Spot gaps in the market, emerging trends, or potential pitfalls (SWOT connection).\n    *   **3. Reduce Risk:** Minimize costly mistakes in product development, marketing, or expansion.\n    *   **4. Gain Competitive Advantage:** Understand your rivals\' strengths and weaknesses to differentiate your offerings.\n    *   **5. Deep Customer Understanding:** Tailor products, services, and marketing messages to specific needs.\n    *   **6. Optimize Resource Allocation:** Invest time and money where it will yield the best returns.\n    *   **7. Validate Business Ideas:** Before investing heavily, ensure there\'s a viable market.\n\n### III. Key Components of a Comprehensive Market Analysis (The "What to Look For") (Approx. 300 words)\n\n*   **A. Target Market Analysis:**\n    *   **1. Demographics:** Age, gender, income, education, occupation, location.\n    *   **2. Psychographics:** Lifestyle, values, interests, attitudes, personality.\n    *   **3. Needs & Pain Points:** What problems are they trying to solve? What are their unmet desires?\n    *   **4. Buying Behavior:** How do they make purchasing decisions? What influences them?\n    *   **5. Market Segmentation:** How can you group your audience for more targeted efforts?\n*   **B. Competitor Analysis:**\n    *   **1. Identify Direct & Indirect Competitors:** Who are they?\n    *   **2. Analyze Their Offerings:** Products, services, pricing, features.\n    *   **3. Assess Strengths & Weaknesses:** What do they do well? Where do they fall short?\n    *   **4. Marketing & Sales Strategies:** How do they reach customers? What\'s their messaging?\n    *   **5. Market Share & Growth:** Ho ...

# %%
print(finalState['content'])
# Out:
# Here's a detailed outline for a blog post on "Market Analysis," designed to be comprehensive, engaging, and actionable for readers.
#
# ---
#
# ## Blog Title Ideas:
#
# *   Market Analysis: Your Ultimate Compass for Business Success
# *   Navigate the Business Landscape: A Comprehensive Guide to Market Analysis
# *   Unlock Growth: The Power of Strategic Market Analysis
# *   Beyond Gut Feeling: Why Market Analysis is Your Business Superpower
# *   Mastering Market Analysis: From Data to Dominance
#
# ---
#
# ## Detailed Blog Outline: Market Analysis: Your Ultimate Compass for Business Success
#
# **Target Audience:** Entrepreneurs, small business owners, marketing professionals, product managers, aspiring business strategists.
#
# **Goal:** To educate readers on what market analysis is, why it's crucial, how to conduct it effectively, and how to leverage its insights for strategic decision-making and business growth.
#
# ---
#
# ### I. Introduction: Setting the Stage (Approx. 150 words)
#
# *   **A. Hook:** Start with a relatable scenario – the uncertainty of launching a product, entering a new market, or facing stiff competition. "Ever felt like you're sailing a ship without a map in the vast ocean of business?"
# *   **B. Introduce Market Analysis:** Briefly define it as the systematic process of gathering, analyzing, and interpreting information about a market, including its customers, competitors, and trends.
# *   **C. State the Blog's Purpose:** Emphasize that this guide will demystify market analysis, showing readers why it's indispensable and how to perform it to gain a competitive edge.
# *   **D. Thesis Statement:** Market analysis isn't just a buzzword; it's the bedrock of informed decision-making, risk reduction, and sustainable growth for any business.
#
# ### II. What Exactly is Market Analysis & Why Does It Matter? (Approx. 200 words)
#
# *   **A. Deeper Definition:**
#     *   More than just data collection; it's about understanding the "why" behind market dynamics.
#     *   Encompasses demand, supply, pricing, competition, customer behavior, and future potential.
# *   **B. Why It's Indispensable: The Core Benefits**
#     *   **1. Informed Decision-Making:** Move beyond assumptions and gut feelings.
#     *   **2. Identify Opportunities & Threats:** Spot gaps in the market, emerging trends, or potential pitfalls (SWOT connection).
#     *   **3. Reduce Risk:** Minimize costly mistakes in product development, marketing, or expansion.
#     *   **4. Gain Competitive Advantage:** Understand your rivals' strengths and weaknesses to differentiate your offerings.
#     *   **5. Deep Customer Understanding:** Tailor products, services, and marketing messages to specific needs.
#     *   **6. Optimize Resource Allocation:** Invest time and money where it will yield the best returns.
#     *   **7. Validate Business Ideas:** Before investing heavily, ensure there's a viable market.
#
# ### III. Key Components of a Comprehensive Market Analysis (The "What to Look For") (Approx. 300 words)
#
# *   **A. Target Market Analysis:**
#     *   **1. Demographics:** Age, gender, income, education, occupation, location.
#     *   **2. Psychographics:** Lifestyle, values, interests, attitudes, personality.
#     *   **3. Needs & Pain Points:** What problems are they trying to solve? What are their unmet desires?
#     *   **4. Buying Behavior:** How do they make purchasing decisions? What influences them?
#     *   **5. Market Segmentation:** How can you group your audience for more targeted efforts?
# *   **B. Competitor Analysis:**
#     *   **1. Identify Direct & Indirect Competitors:** Who are they?
#     *   **2. Analyze Their Offerings:** Products, services, pricing, features.
#     *   **3. Assess Strengths & Weaknesses:** What do they do well? Where do they fall short?
#     *   **4. Marketing & Sales Strategies:** How do they reach customers? What's their messaging?
#     *   **5. Market Share & Growth:** How big are they? Are they growing?
# *   **C. Industry & Trend Analysis:**
#     *   **1. Market Size & Growth Rate:** Is the market expanding, contracting, or stable?
#     *   **2. PESTEL Analysis (Brief Mention):** Political, Economic, Social, Technological, Environmental, Legal factors influencing the industry.
#     *   **3. Emerging Technologies & Disruptions:** What innovations are on the horizon?
#     *   **4. Regulatory Environment:** Any laws or policies that could impact your business?
# *   **D. Market Size & Potential:**
#     *   **1. Total Addressable Market (TAM):** The entire market demand for a product or service.
#     *   **2. Serviceable Available Market (SAM):** The portion of TAM that your business can realistically serve.
#     *   **3. Serviceable Obtainable Market (SOM):** The slice of SAM you can realistically capture.
#
# ### IV. How to Conduct Market Analysis: A Step-by-Step Guide (The "How-To") (Approx. 400 words)
#
# *   **A. Step 1: Define Your Objectives & Scope:**
#     *   What specific questions do you want to answer? (e.g., "Is there demand for X product?", "Which market segment should we target?")
#     *   What's the scope of your analysis (geographical, product-specific)?
# *   **B. Step 2: Gather Data (Primary & Secondary Research):**
#     *   **1. Secondary Research (Start Here):**
#         *   **Sources:** Industry reports (IBISWorld, Gartner), government statistics (census data), academic studies, trade publications, competitor websites, public financial statements, news articles.
#         *   **Pros:** Cost-effective, readily available.
#         *   **Cons:** Might not be specific enough, potentially outdated.
#     *   **2. Primary Research (For Specific Insights):**
#         *   **Methods:** Surveys (online, phone), interviews (one-on-one with experts/customers), focus groups, observation, field experiments.
#         *   **Pros:** Tailored to your needs, current, specific insights.
#         *   **Cons:** Time-consuming, expensive, requires careful design.
# *   **C. Step 3: Analyze the Data:**
#     *   **1. Quantitative Analysis:** Look for patterns, correlations, statistical significance (e.g., market size calculations, growth rates).
#     *   **2. Qualitative Analysis:** Interpret themes, opinions, and motivations from interviews/focus groups.
#     *   **3. Use Frameworks:** Apply SWOT analysis, Porter's Five Forces, PESTEL to structure your findings.
# *   **D. Step 4: Interpret Findings & Draw Conclusions:**
#     *   What do the numbers and narratives *actually mean* for your business?
#     *   Identify key insights, trends, and opportunities.
#     *   Synthesize complex information into clear, concise summaries.
# *   **E. Step 5: Develop Actionable Strategies:**
#     *   Translate your conclusions into concrete plans.
#     *   Examples: Product development roadmap, pricing strategy, marketing campaign focus, market entry/exit strategy.
# *   **F. Step 6: Monitor & Update:**
#     *   Market analysis is not a one-time event. Markets are dynamic.
#     *   Regularly review and update your analysis to stay agile.
#
# ### V. Essential Tools & Resources for Market Analysis (Approx. 150 words)
#
# *   **A. Data Aggregators & Research Firms:** Statista, Gartner, Forrester, Nielsen.
# *   **B. Government & Public Data:** Census Bureau, Bureau of Labor Statistics, SEC filings.
# *   **C. Survey & Feedback Tools:** SurveyMonkey, Google Forms, Typeform.
# *   **D. Competitive Intelligence Tools:** SEMrush, Ahrefs, SimilarWeb, Google Alerts.
# *   **E. CRM & Analytics:** Google Analytics, Salesforce, HubSpot (for customer data).
# *   **F. Spreadsheet Software:** Microsoft Excel, Google Sheets (for organizing and analyzing data).
#
# ### VI. Common Pitfalls to Avoid (Approx. 100 words)
#
# *   **A. Outdated Data:** Relying on old information.
# *   **B. Confirmation Bias:** Only looking for data that supports your existing beliefs.
# *   **C. Over-reliance on Secondary Data:** Neglecting primary research for specific insights.
# *   **D. Analysis Paralysis:** Getting bogged down in data without taking action.
# *   **E. Ignoring Qualitative Data:** Focusing only on numbers and missing the human element.
# *   **F. Not Defining Objectives Clearly:** Wasting time on irrelevant research.
#
# ### VII. The Future of Market Analysis (Approx. 100 words)
#
# *   **A. AI & Machine Learning:** Automating data collection, pattern recognition, predictive analytics.
# *   **B. Big Data & Real-Time Insights:** Leveraging vast datasets for immediate decision-making.
# *   **C. Hyper-Personalization:** Deeper understanding of individual customer journeys.
# *   **D. Ethical Considerations:** Data privacy and responsible use of insights.
#
# ### VIII. Conclusion: Charting Your Course (Approx. 100 words)
#
# *   **A. Recap:** Briefly reiterate the immense value of market analysis as a strategic imperative.
# *   **B. Reiterate the Main Message:** It empowers businesses to make confident, data-driven decisions that lead to sustainable growth and competitive advantage.
# *   **C. Call to Action:** Encourage readers to start implementing market analysis in their own ventures, even on a small scale. "Don't just launch into the market blind; arm yourself with knowledge."
# *   **D. Engaging Question:** "What's one market insight you've gained that transformed your business strategy?" (Encourage comments and interaction).
#
# ---
