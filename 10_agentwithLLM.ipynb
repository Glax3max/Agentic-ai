# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState):
    question = state['question']
    answer = model.invoke(question)
    state['question'] = answer.content
    return state

# %%
graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)
# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)


workFlow = graph.compile()

# %%
initialState = workFlow.invoke({'question':"Tell me about nikola tesla"})
print(initialState)
# Out:
# {'question': 'Nikola Tesla was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist best known for his contributions to the design of the modern alternating current (AC) electricity supply system. He was a visionary ahead of his time, often misunderstood, and his work profoundly shaped the 20th century and beyond.\n\nHere\'s a breakdown of his life and impact:\n\n1.  **Early Life & Education (1856-1884):**\n    *   Born in Smiljan, Austrian Empire (modern-day Croatia) in 1856 to Serbian parents. His father was an Orthodox priest, and his mother was an inventor of household tools.\n    *   He displayed an early aptitude for invention and a photographic memory.\n    *   He studied engineering at the Austrian Polytechnic in Graz and later at the University of Prague, though he never completed a degree.\n    *   His early work included a job at the Continental Edison Company in Paris, where he gained valuable experience in the nascent electrical industry.\n\n2.  **Arrival in America & The "War of the Currents" (1884-1890s):**\n    *   In 1884, Tesla emigrated to the United States, arriving in New York City with little more than a letter of recommendation to Thomas Edison.\n    *   He initially worked for Edison, but their differing views on electrical systems (Edison favored direct current, DC; Tesla championed alternating current, AC) led to a famous split.\n    *   Tesla, with financial backing from George Westinghouse, became the central figure in the "War of the Currents." He developed the polyphase alternating current (AC) system, including the AC motor, transformer, and power transmission system.\n    *   His AC system proved to be far more efficient for transmitting electricity over long distances than Edison\'s DC system, which suffered significant power loss.\n    *   The AC system\'s triumph was cemented by its use to power the 1893 World\'s Columbian Exposition in Chicago and, crucially, to harness the power of Niagara Falls in 1895, providing electricity to Buffalo, New York. This established AC as the standard for power generation and distribution worldwide.\n\n3.  **Other Major Inventions & Visions:**\n    *   **Tesla Coil:** Invented in 1891, this resonant transformer circuit is used to produce high-voltage, low-current, high-frequency alternating-current electricity. It\'s still used today in radio and television sets, and for educational demonstrations.\n    *   **Radio Technology:** Tesla performed early demonstrations of wireless communication and remote control. While Guglielmo Marconi is credited with the invention of radio, the U.S. Supreme Court in 1943 upheld Tesla\'s earlier patents related to radio technology.\n    *   **Remote Control:** In 1898, he demonstrated a radio-controlled boat at Madison Square Garden, an early precursor to robotics and remote-controlled devices.\n    *   **X-rays:** He conducted pioneering experiments with X-rays around the same time as Wilhelm Röntgen.\n    *   **Wireless Power Transmission:** Tesla envisioned a world where electricity could be transmitted wirelessly. His most ambitious project, the **Wardenclyffe Tower** on Long Island, was an attempt to build a global wireless power and communication system, but it was never completed due to financial difficulties.\n    *   **Fluorescent and Neon Lighting:** Tesla contributed to the development of these forms of lighting.\n    *   **Hydroelectric Power:** His work at Niagara Falls was instrumental in establishing the viability of large-scale hydroelectric power.\n\n4.  **Personality & Eccentricities:**\n    *   Tesla was known for his elegant dress, reclusive nature, and peculiar habits.\n    *   He had a photographic memory and could visualize complex inventions in his mind without needing to draw them.\n    *   He was a germaphobe and had an obsession with numbers divisible by three.\n    *   He was celibate throughout his life, believing it aided his scientific work.\n    *   In his later ye ...
