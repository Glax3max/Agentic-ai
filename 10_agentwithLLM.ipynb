# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState):
    question = state['question']
    answer = model.invoke(question)
    state['question'] = answer.content
    return state

# %%
graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)
# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)


workFlow = graph.compile()

# %%
initialState = workFlow.invoke({'question':"Tell me about nikola tesla"})
print(initialState)
# Out:
# {'question': 'Nikola Tesla was a Serbian-American inventor, electrical engineer, mechanical engineer, and futurist who is best known for his contributions to the design of the modern alternating current (AC) electricity supply system. He was a true visionary whose work laid the foundation for much of our modern technological world.\n\nHere\'s a breakdown of his life and key contributions:\n\n1.  **Early Life and Education (1856-1884):**\n    *   Born in Smiljan, Austrian Empire (modern-day Croatia) to Serbian parents.\n    *   Showed an early aptitude for invention and a prodigious memory.\n    *   Studied engineering at the Realschule in Graz, Austria, and later at the University of Prague.\n    *   While studying, he first conceived the idea of the rotating magnetic field, which would be crucial for his AC motor.\n    *   Worked for a telephone company in Budapest and later for Continental Edison in Paris, where he designed and improved electrical equipment.\n\n2.  **Arrival in America and Work with Edison (1884-1885):**\n    *   Emigrated to the United States in 1884 with little more than a letter of recommendation to Thomas Edison.\n    *   Edison hired him, and Tesla quickly impressed him with his engineering skills, reportedly solving complex problems for Edison\'s DC (direct current) dynamos.\n    *   However, their working relationship was short-lived and contentious, largely due to differences in personality and the famous "bet" over DC motor improvements (where Edison allegedly promised $50,000, then dismissed it as a joke). Tesla quit.\n\n3.  **The AC Revolution and "War of the Currents" (1886-1890s):**\n    *   After a brief period of hardship, digging ditches, Tesla found investors for the Tesla Electric Light & Manufacturing Company.\n    *   His most significant breakthrough was the **alternating current (AC) induction motor and the polyphase AC system**. Unlike Edison\'s DC system, AC could be transmitted efficiently over long distances at high voltages and then stepped down for safe use.\n    *   **George Westinghouse** recognized the superiority of Tesla\'s AC system and licensed his patents. This led to the "War of the Currents," a bitter public relations battle between Edison (championing DC) and Westinghouse/Tesla (championing AC). Edison, fearing loss of his DC empire, resorted to scare tactics, including publicly electrocuting animals with AC.\n    *   **Victory for AC:** Tesla\'s system ultimately prevailed. The crowning achievement was the illumination of the **Chicago World\'s Columbian Exposition in 1893** and the subsequent construction of the **Niagara Falls hydroelectric power plant** (1895), which used Tesla\'s AC generators to power Buffalo, New York, marking a global shift to AC.\n\n4.  **Other Key Inventions and Ideas:**\n    *   **Tesla Coil (1891):** An electrical resonant transformer circuit used to produce high-voltage, low-current, high-frequency alternating-current electricity. It\'s still used in radio and television sets and for scientific research.\n    *   **Radio Technology:** While Guglielmo Marconi is often credited with inventing radio, Tesla performed demonstrations of radio communication as early as 1893 and had patents for fundamental radio technology. The U.S. Supreme Court ultimately upheld Tesla\'s radio patent in 1943, after his death.\n    *   **Remote Control:** Demonstrated the world\'s first radio-controlled boat in 1898 at Madison Square Garden.\n    *   **X-ray Imaging:** Conducted early experiments with X-rays.\n    *   **Wireless Energy Transmission (Wardenclyffe Tower):** Tesla envisioned a global system for wireless power and communication. He began building Wardenclyffe Tower on Long Island, New York, in the early 1900s, but funding ran out, and the project was never completed. It was a grand, but ultimately unrealized, dream.\n    *   **Turbines:** Designed bladeless turbines.\n    *   **Robotics:** Envisioned and discussed the concept of intelligent robots.\n  ...
